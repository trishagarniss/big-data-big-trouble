# %%
import os, sys
os.chdir(os.path.dirname(os.getcwd()))
sys.path.insert(0, os.getcwd())

# %% [markdown]
# # Libraries

# %%
import pandas as pd
from pathlib import Path
from modules.utils import load_train, load_test, load_submission_example

# %% [markdown]
# # Dataset

# %%
df_train = load_train()
df_train.head(20)
# Out:
#                                       path         label
# 0      data\raw\train\0_Recyclable\R_1.jpg  0_Recyclable
# 1     data\raw\train\0_Recyclable\R_10.jpg  0_Recyclable
# 2    data\raw\train\0_Recyclable\R_100.jpg  0_Recyclable
# 3   data\raw\train\0_Recyclable\R_1000.jpg  0_Recyclable
# 4   data\raw\train\0_Recyclable\R_1001.jpg  0_Recyclable
# 5   data\raw\train\0_Recyclable\R_1002.jpg  0_Recyclable
# 6   data\raw\train\0_Recyclable\R_1003.jpg  0_Recyclable
# 7   data\raw\train\0_Recyclable\R_1004.jpg  0_Recyclable
# 8   data\raw\train\0_Recyclable\R_1005.jpg  0_Recyclable
# 9   data\raw\train\0_Recyclable\R_1006.jpg  0_Recyclable
# 10  data\raw\train\0_Recyclable\R_1007.jpg  0_Recyclable
# 11  data\raw\train\0_Recyclable\R_1008.jpg  0_Recyclable
# 12  data\raw\train\0_Recyclable\R_1009.jpg  0_Recyclable
# 13   data\raw\train\0_Recyclable\R_101.jpg  0_Recyclable
# 14  data\raw\train\0_Recyclable\R_1010.jpg  0_Recyclable
# 15  data\raw\train\0_Recyclable\R_1011.jpg  0_Recyclable
# 16  data\raw\train\0_Recyclable\R_1012.jpg  0_Recyclable
# 17  data\raw\train\0_Recyclable\R_1013.jpg  0_Recyclable
# 18  data\raw\train\0_Recyclable\R_1014.jpg  0_Recyclable
# 19  data\raw\train\0_Recyclable\R_1015.jpg  0_Recyclable

# %%
df_test = load_test()
df_test.head()
# Out:
#                      path image_id
# 0     data/raw/test/1.jpg        1
# 1    data/raw/test/10.jpg       10
# 2   data/raw/test/100.jpg      100
# 3  data/raw/test/1000.jpg     1000
# 4  data/raw/test/1001.jpg     1001

# %%
df_sub = load_submission_example()
df_sub.head()
# Out:
#    id  predicted
# 0   1        NaN
# 1   2        NaN
# 2   3        NaN
# 3   4        NaN
# 4   5        NaN

# %% [markdown]
# # EDA

# %%
df_train.shape
# Out:
# (26527, 2)
